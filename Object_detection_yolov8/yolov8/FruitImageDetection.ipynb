# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 195MB/s]

# %%
# !touch data.yaml

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e21a8712-d032-4352-b257-6c49e33e711e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e21a8712-d032-4352-b257-6c49e33e711e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mbkinaci/fruit-images-for-object-detection
# Out:
# ...
#  88% 25.0M/28.4M [00:01<00:00, 24.0MB/s]
# 100% 28.4M/28.4M [00:01<00:00, 19.9MB/s]

# %%
# !unzip -q fruit-images-for-object-detection

# %%
model.train(data = "/content/data.yaml", epochs = 100)
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
detector = YOLO("/content/runs/detect/train3/weights/best.pt")

# %%
model.predict(source = '/content/FruitImages/test_zip/test', save = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-652181fab141> in <cell line: 1>()
# ----> 1 model.predict(source = '/content/FruitImages/test_zip/test', save = True)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     273         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     274             self.predictor.set_prompts(prompts)
# --> 275         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     276
#     277     def track(self, source=None, stream=False, persist=False, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...
