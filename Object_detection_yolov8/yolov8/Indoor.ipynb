# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s")

# %%
# !touch data.yaml

# %%
# !unzip '/content/dataset.zip' -d "/content/dataset"

# %%
model.train(data='/content/data.yaml',epochs = 100)
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
detector = YOLO("/content/runs/detect/train4/weights/best.pt")

# %%
model.predict(source = '/content/dataset/dataset/val/images', save = True)
# Out:
# image 1/22 /content/dataset/dataset/val/images/1 (41).jpeg: 640x640 2 sofas, 16.3ms
# image 2/22 /content/dataset/dataset/val/images/1 (42).jpeg: 640x640 6 sofas, 16.4ms
# image 3/22 /content/dataset/dataset/val/images/1 (43).jpeg: 640x640 1 clock, 3 sofas, 16.3ms
# image 4/22 /content/dataset/dataset/val/images/1 (44).jpeg: 640x640 1 clock, 3 sofas, 16.8ms
# image 5/22 /content/dataset/dataset/val/images/1 (45).jpeg: 640x640 2 sofas, 16.8ms
# image 6/22 /content/dataset/dataset/val/images/1 (46).jpeg: 640x640 3 sofas, 16.3ms
# image 7/22 /content/dataset/dataset/val/images/1 (47).jpeg: 640x640 1 clock, 4 sofas, 16.3ms
# image 8/22 /content/dataset/dataset/val/images/1 (48).jpeg: 640x640 4 sofas, 16.3ms
# image 9/22 /content/dataset/dataset/val/images/1 (49).jpeg: 640x640 4 sofas, 14.4ms
# image 10/22 /content/dataset/dataset/val/images/1 (50).jpeg: 544x640 9 sofas, 85.5ms
# image 11/22 /content/dataset/dataset/val/images/1 (51).jpeg: 640x640 1 clock, 2 sofas, 12.2ms
# ...

# %%
# data.yaml including code

# train: /content/dataset/dataset/train
# val: /content/dataset/dataset/val
# nc: 5
# names:
#   - cup
#   - clock
#   - pillow
#   - sofa
#   - table
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-12-a0dd41e94bf9>, line 1)
