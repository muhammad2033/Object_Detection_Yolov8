# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8m.pt')

# %%
# !touch data.yaml

# %%
# !unzip "/content/FootBallDataset"
# Out:
# Archive:  /content/FootBallDataset.zip
#    creating: FootBallDataset/
#    creating: FootBallDataset/images/
#    creating: FootBallDataset/images/train/
#   inflating: FootBallDataset/images/train/22d_f_120_6ty.jpg
#   inflating: FootBallDataset/images/train/22d_f_125.jpg
#   inflating: FootBallDataset/images/train/22d_f_125_fre.jpg
#   inflating: FootBallDataset/images/train/22d_f_135_we.jpg
#   inflating: FootBallDataset/images/train/22d_f_15_rt3.jpg
#   inflating: FootBallDataset/images/train/22d_f_165_fr.jpg
#   inflating: FootBallDataset/images/train/22d_f_180_6ty.jpg
#   inflating: FootBallDataset/images/train/22d_f_185_6ty.jpg
#   inflating: FootBallDataset/images/train/22d_f_200_rt3.jpg
#   inflating: FootBallDataset/images/train/22d_f_25.jpg
#   inflating: FootBallDataset/images/train/22d_f_30_22d.jpg
#   inflating: FootBallDataset/images/train/22d_f_55_22d.jpg
#   inflating: FootBallDataset/images/train/22d_f_80.jpg
# ...

# %%
model.train(data='/content/data.yaml', epochs = 100)
# Out:
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
detector = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
model.predict(source = '/content/FootBallDataset/images/val', save= True, )
# Out:
# image 1/6 /content/FootBallDataset/images/val/6ty_f_110_54r.jpg: 384x640 12 Players, 1 football, 81.3ms
# image 2/6 /content/FootBallDataset/images/val/6ty_f_50_we.jpg: 384x640 12 Players, 1 football, 25.3ms
# image 3/6 /content/FootBallDataset/images/val/6ty_f_65_we.jpg: 384x640 13 Players, 1 football, 25.3ms
# image 4/6 /content/FootBallDataset/images/val/6ty_f_80_54r.jpg: 384x640 12 Players, 1 football, 25.3ms
# image 5/6 /content/FootBallDataset/images/val/6ty_f_85.jpg: 384x640 8 Players, 27.5ms
# image 6/6 /content/FootBallDataset/images/val/6ty_f_90_we.jpg: 384x640 14 Players, 25.3ms
# Speed: 3.4ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Player', 1: 'football'}
#  obb: None
#  orig_img: array([[[113, 130, 121],
# ...
