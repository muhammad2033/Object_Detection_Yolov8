# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO("yolov8s")
# !touch data.yaml
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 201MB/s]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ba9c45f-a5c8-40d5-bea4-68fe47616358" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ba9c45f-a5c8-40d5-bea4-68fe47616358">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -dthepbordin/indoor-object-detection
# Out:
# ...
# 100% 366M/367M [00:05<00:00, 115MB/s]
# 100% 367M/367M [00:05<00:00, 69.8MB/s]

# %%
# !unzip -q indoor-object-detection
# Out:
# replace data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %%
model.train(data = "/content/data.yaml", epochs = 100)
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
detector = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
model.predict(source = '/content/valid/images', save = True)
# Out:
# image 1/230 /content/valid/images/000cf08de329f81b.jpg: 480x640 2 doors, 165.3ms
# image 2/230 /content/valid/images/000d61ba9ffa87db.jpg: 448x640 1 refrigeratorDoor, 119.9ms
# image 3/230 /content/valid/images/00bb967bc89e040f.jpg: 640x480 7 doors, 2 windows, 111.3ms
# image 4/230 /content/valid/images/00c4503acd511444.jpg: 640x480 5 doors, 12.3ms
# image 5/230 /content/valid/images/00cb40d7ea24aa3b.jpg: 640x448 5 doors, 1 window, 125.0ms
# image 6/230 /content/valid/images/00ce3c2f4657457f.jpg: 448x640 2 doors, 3 cabinetDoors, 13.9ms
# image 7/230 /content/valid/images/00dbfb71d81618ea.jpg: 480x640 4 doors, 14.2ms
# image 8/230 /content/valid/images/00de93955694a159.jpg: 640x640 1 refrigeratorDoor, 20.1ms
# image 9/230 /content/valid/images/0118064eedc2b2c1.jpg: 640x640 3 doors, 3 cabinetDoors, 1 refrigeratorDoor, 18.5ms
# image 10/230 /content/valid/images/022594ed9ec74a86.jpg: 448x640 4 cabinetDoors, 7 refrigeratorDoors, 14.7ms
# ...

# %%
model.load_state_dict(torch.load('yolov8n.pt'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-d67668096f9f> in <cell line: 1>()
# ----> 1 model.load_state_dict(torch.load('yolov8n.pt'))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2150
#    2151         if len(error_msgs) > 0:
# -> 2152             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for YOLO:
# ...
